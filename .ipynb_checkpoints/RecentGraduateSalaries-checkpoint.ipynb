# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv(r'C:\Users\CLEMO\RecentGraduateSalaries\recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads = recent_grads.dropna()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %%
recent_grads.plot(x='Sample_size', y='Median', kind= 'scatter')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind= 'scatter')

# %%
recent_grads.plot(x='Full_time', y='Median', kind= 'scatter')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind= 'scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind= 'scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind= 'scatter')

# %% [markdown]
# ## Histograms

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %% [markdown]
# The above histogram has been set to a range of 5000 and subdivided into 25 bins, each of size 200.

# %%
recent_grads['Median'].hist(bins=150, range=(0,150000))

# %%
recent_grads['Employed'].hist(bins=31, range=(0,310000))

# %%
recent_grads['Full_time'].hist(bins=26, range=(0,260000))

# %%
recent_grads['ShareWomen'].hist(bins=5, range=(0,1))

# %%
recent_grads['Unemployment_rate'].hist(bins=4, range=(0,0.2))

# %%
recent_grads['Women'].describe()
# Out:
# count       172.000000
# mean      22646.674419
# std       41057.330740
# min           0.000000
# 25%        1778.250000
# 50%        8386.500000
# 75%       22553.750000
# max      307087.000000
# Name: Women, dtype: float64

# %%
recent_grads['Men'].hist(bins=18, range=(0,180000))

# %%
recent_grads['Women'].hist(bins=31, range=(0,310000))

# %% [markdown]
# ## Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000178E35E7940>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000178E2DC3198>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar Plots

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')
